# %%
import pandas as pd
from numpy import *
from sklearn import *
random.seed(56115335)

# %%
data_file = pd.read_csv('data-preprocessing/listing-processed.csv', low_memory=False)
data_file.shape
# Out:
# (24194, 69)

# %%
data_file
# Out:
#        Unnamed: 0        id    host_id    host_since  host_response_time  \
# 0               0      9835      33057  1.250784e+09                 0.0
# 1               1     10803      38901  1.253030e+09                -1.0
# 2               2     12936      50121  1.256918e+09                -1.0
# 3               3     15246      59786  1.259770e+09                 0.0
# 4               4     16760      65090  1.261411e+09                -5.0
# ...           ...       ...        ...           ...                 ...
# 24189       24189  38610335  285240939  1.565626e+09                -5.0
# 24190       24190  38610345  160772288  1.511971e+09                -5.0
# 24191       24191  38610653  285240939  1.565626e+09                -5.0
# 24192       24192  38612012   50268144  1.448899e+09                 0.0
# 24193       24193  38613509   50405671  1.448986e+09                -1.0
#
#       host_response_rate  host_acceptance_rate  host_is_superhost  \
# ...
